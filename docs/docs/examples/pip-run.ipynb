# %%
import os
os.environ['OPENAI_API_KEY'] = 'sk-zVz0CAJ9YcbfdDX45rR2nAh7259Sfl9betsMNn51zg5cxk1y'
os.environ['TAVILY_API_KEY'] = 'your_tavily_api_key' # Get a free key here: https://app.tavily.com

# %%
# !pip install -U gpt-researcher nest_asyncio
# Out:
# Looking in indexes: https://mirrors.bfsu.edu.cn/pypi/web/simple
# Requirement already satisfied: gpt-researcher in c:\python\lib\site-packages (0.12.5)
# Requirement already satisfied: nest_asyncio in c:\python\lib\site-packages (1.6.0)
# Requirement already satisfied: beautifulsoup4 in c:\python\lib\site-packages (from gpt-researcher) (4.12.3)
# Requirement already satisfied: colorama in c:\python\lib\site-packages (from gpt-researcher) (0.4.6)
# Requirement already satisfied: md2pdf in c:\python\lib\site-packages (from gpt-researcher) (1.0.1)
# Requirement already satisfied: python-dotenv in c:\python\lib\site-packages (from gpt-researcher) (1.0.1)
# Requirement already satisfied: pyyaml in c:\python\lib\site-packages (from gpt-researcher) (6.0.2)
# Requirement already satisfied: pydantic in c:\python\lib\site-packages (from gpt-researcher) (2.10.6)
# Requirement already satisfied: python-multipart in c:\python\lib\site-packages (from gpt-researcher) (0.0.9)
# Requirement already satisfied: markdown in c:\python\lib\site-packages (from gpt-researcher) (3.4.1)
# Requirement already satisfied: langchain in c:\python\lib\site-packages (from gpt-researcher) (0.1.17)
# Requirement already satisfied: langchain-community in c:\python\lib\site-packages (from gpt-researcher) (0.0.38)
# Requirement already satisfied: langchain-openai in c:\python\lib\site-packages (from gpt-researcher) (0.0.8)
# Requirement already satisfied: tiktoken in c:\python\lib\site-packages (from gpt-researcher) (0.7.0)
# Requirement already satisfied: arxiv in c:\python\lib\site-packages (from gpt-researcher) (2.1.3)
# Requirement already satisfied: PyMuPDF in c:\python\lib\site-packages (from gpt-researcher) (1.25.3)
# Requirement already satisfied: requests in c:\python\lib\site-packages (from gpt-researcher) (2.32.3)
# Requirement already satisfied: aiofiles in c:\python\lib\site-packages (from gpt-researcher) (24.1.0)
# Requirement already satisfied: mistune in c:\python\lib\site-packages (from gpt-researcher) (0.8.4)
# Requirement already satisfied: python-docx in c:\python\lib\site-packages (from gpt-researcher) (1.1.2)
# Requirement already satisfied: htmldocx in c:\python\lib\site-packages (from gpt-researcher) (0.0.6)
# Requirement already satisfied: lxml-html-clean in c:\python\lib\site-packages (from gpt-researcher) (0.4.1)
# Requirement already satisfied: websockets in c:\python\lib\site-packages (from gpt-researcher) (15.0)
# Requirement already satisfied: unstructured in c:\python\lib\site-packages (from gpt-researcher) (0.16.23)
# Requirement already satisfied: json-repair in c:\python\lib\site-packages (from gpt-researcher) (0.39.1)
# Requirement already satisfied: json5 in c:\python\lib\site-packages (from gpt-researcher) (0.9.6)
# Requirement already satisfied: loguru in c:\python\lib\site-packages (from gpt-researcher) (0.7.3)
# Requirement already satisfied: feedparser~=6.0.10 in c:\python\lib\site-packages (from arxiv->gpt-researcher) (6.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\lib\site-packages (from requests->gpt-researcher) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\lib\site-packages (from requests->gpt-researcher) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\lib\site-packages (from requests->gpt-researcher) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\lib\site-packages (from requests->gpt-researcher) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\python\lib\site-packages (from beautifulsoup4->gpt-researcher) (2.4)
# Requirement already satisfied: lxml>=3.1.0 in c:\python\lib\site-packages (from python-docx->gpt-researcher) (4.9.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\python\lib\site-packages (from python-docx->gpt-researcher) (4.12.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\python\lib\site-packages (from langchain->gpt-researcher) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\python\lib\site-packages (from langchain->gpt-researcher) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\python\lib\site-packages (from langchain->gpt-researcher) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\python\lib\site-packages (from langchain->gpt-researcher) (1.33)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in c:\python\lib\site-packages (from langchain->gpt-researcher) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\python\lib\site-packages (from langchain->gpt-researcher) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\python\lib\site-packages (from langchain->gpt-researcher) (0.1.84)
# Requirement already satisfied: numpy<2,>=1 in c:\python\lib\site-packages (from langchain->gpt-researcher) (1.26.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\python\lib\site-packages (from langchain->gpt-researcher) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python\lib\site-packages (from pydantic->gpt-researcher) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\python\lib\site-packages (from pydantic->gpt-researcher) (2.27.2)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in c:\python\lib\site-packages (from langchain-openai->gpt-researcher) (1.35.12)
# Requirement already satisfied: regex>=2022.1.18 in c:\python\lib\site-packages (from tiktoken->gpt-researcher) (2022.7.9)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\python\lib\site-packages (from loguru->gpt-researcher) (1.2.0)
# Requirement already satisfied: docopt in c:\python\lib\site-packages (from md2pdf->gpt-researcher) (0.6.2)
# Requirement already satisfied: WeasyPrint in c:\python\lib\site-packages (from md2pdf->gpt-researcher) (64.1)
# Requirement already satisfied: markdown2 in c:\python\lib\site-packages (from md2pdf->gpt-researcher) (2.5.3)
# Requirement already satisfied: chardet in c:\python\lib\site-packages (from unstructured->gpt-researcher) (4.0.0)
# Requirement already satisfied: filetype in c:\python\lib\site-packages (from unstructured->gpt-researcher) (1.2.0)
# Requirement already satisfied: python-magic in c:\python\lib\site-packages (from unstructured->gpt-researcher) (0.4.27)
# Requirement already satisfied: nltk in c:\python\lib\site-packages (from unstructured->gpt-researcher) (3.8.1)
# Requirement already satisfied: emoji in c:\python\lib\site-packages (from unstructured->gpt-researcher) (2.14.1)
# Requirement already satisfied: python-iso639 in c:\python\lib\site-packages (from unstructured->gpt-researcher) (2025.2.18)
# Requirement already satisfied: langdetect in c:\python\lib\site-packages (from unstructured->gpt-researcher) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\python\lib\site-packages (from unstructured->gpt-researcher) (3.9.4)
# Requirement already satisfied: backoff in c:\python\lib\site-packages (from unstructured->gpt-researcher) (2.2.1)
# Requirement already satisfied: unstructured-client in c:\python\lib\site-packages (from unstructured->gpt-researcher) (0.30.4)
# Requirement already satisfied: wrapt in c:\python\lib\site-packages (from unstructured->gpt-researcher) (1.14.1)
# Requirement already satisfied: tqdm in c:\python\lib\site-packages (from unstructured->gpt-researcher) (4.66.1)
# Requirement already satisfied: psutil in c:\python\lib\site-packages (from unstructured->gpt-researcher) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\python\lib\site-packages (from unstructured->gpt-researcher) (0.0.2)
# Requirement already satisfied: html5lib in c:\python\lib\site-packages (from unstructured->gpt-researcher) (1.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->gpt-researcher) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\python\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->gpt-researcher) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\python\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->gpt-researcher) (0.9.0)
# Requirement already satisfied: sgmllib3k in c:\python\lib\site-packages (from feedparser~=6.0.10->arxiv->gpt-researcher) (1.0.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\python\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain->gpt-researcher) (2.1)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\python\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain->gpt-researcher) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\python\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain->gpt-researcher) (3.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\python\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\python\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\python\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (0.27.0)
# Requirement already satisfied: sniffio in c:\python\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->gpt-researcher) (2.0.1)
# Requirement already satisfied: six>=1.9 in c:\python\lib\site-packages (from html5lib->unstructured->gpt-researcher) (1.16.0)
# Requirement already satisfied: webencodings in c:\python\lib\site-packages (from html5lib->unstructured->gpt-researcher) (0.5.1)
# Requirement already satisfied: click in c:\python\lib\site-packages (from nltk->unstructured->gpt-researcher) (8.1.8)
# Requirement already satisfied: joblib in c:\python\lib\site-packages (from nltk->unstructured->gpt-researcher) (1.2.0)
# Requirement already satisfied: olefile in c:\python\lib\site-packages (from python-oxmsg->unstructured->gpt-researcher) (0.47)
# Requirement already satisfied: cryptography>=3.1 in c:\python\lib\site-packages (from unstructured-client->unstructured->gpt-researcher) (41.0.2)
# Requirement already satisfied: eval-type-backport>=0.2.0 in c:\python\lib\site-packages (from unstructured-client->unstructured->gpt-researcher) (0.2.2)
# Requirement already satisfied: pypdf>=4.0 in c:\python\lib\site-packages (from unstructured-client->unstructured->gpt-researcher) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\lib\site-packages (from unstructured-client->unstructured->gpt-researcher) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\python\lib\site-packages (from unstructured-client->unstructured->gpt-researcher) (1.0.0)
# Requirement already satisfied: pydyf>=0.11.0 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (0.11.0)
# Requirement already satisfied: cffi>=0.6 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (1.15.1)
# Requirement already satisfied: tinyhtml5>=2.0.0b1 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (2.0.0)
# Requirement already satisfied: tinycss2>=1.4.0 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (1.4.0)
# Requirement already satisfied: cssselect2>=0.1 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (0.17.2)
# Requirement already satisfied: Pillow>=9.1.0 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (9.4.0)
# Requirement already satisfied: fonttools[woff]>=4.0.0 in c:\python\lib\site-packages (from WeasyPrint->md2pdf->gpt-researcher) (4.25.0)
# Requirement already satisfied: pycparser in c:\python\lib\site-packages (from cffi>=0.6->WeasyPrint->md2pdf->gpt-researcher) (2.21)
# Requirement already satisfied: zopfli>=0.1.4 in c:\python\lib\site-packages (from fonttools[woff]>=4.0.0->WeasyPrint->md2pdf->gpt-researcher) (0.2.3.post1)
# Requirement already satisfied: brotli>=1.0.1 in c:\python\lib\site-packages (from fonttools[woff]>=4.0.0->WeasyPrint->md2pdf->gpt-researcher) (1.1.0)
# Requirement already satisfied: httpcore==1.* in c:\python\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai->gpt-researcher) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\python\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->gpt-researcher) (0.4.3)

# %%
import nest_asyncio # required for notebooks
nest_asyncio.apply()

from gpt_researcher import GPTResearcher
import asyncio

async def get_report(query: str, report_type: str) -> str:
    researcher = GPTResearcher(query, report_type)
    research_result = await researcher.conduct_research()
    report = await researcher.write_report()
    
    # Get additional information
    research_context = researcher.get_research_context()
    research_costs = researcher.get_costs()
    research_images = researcher.get_research_images()
    research_sources = researcher.get_research_sources()
    
    return report, research_context, research_costs, research_images, research_sources

if __name__ == "__main__":
    query = "Should I invest in Nvidia?"
    report_type = "research_report"

    report, context, costs, images, sources = asyncio.run(get_report(query, report_type))
    
    print("Report:")
    print(report)
    print("\nResearch Costs:")
    print(costs)
    print("\nResearch Images:")
    print(images)
    print("\nResearch Sources:")
    print(sources)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 import nest_asyncio # required for notebooks
#       2 nest_asyncio.apply()
# ----> 4 from gpt_researcher import GPTResearcher
#       5 import asyncio
#       7 async def get_report(query: str, report_type: str) -> str:
#
# File C:\python\Lib\site-packages\gpt_researcher\__init__.py:1
# ----> 1 from .agent import GPTResearcher
#       3 __all__ = ['GPTResearcher']
#
# File C:\python\Lib\site-packages\gpt_researcher\agent.py:11
#       8 from .vector_store import VectorStoreWrapper
#      10 # Research skills
# ---> 11 from .skills.researcher import ResearchConductor
#      12 from .skills.writer import ReportGenerator
#      13 from .skills.context_manager import ContextManager
#
# File C:\python\Lib\site-packages\gpt_researcher\skills\__init__.py:1
# ----> 1 from .context_manager import ContextManager
#       2 from .researcher import ResearchConductor
#       3 from .writer import ReportGenerator
#
# File C:\python\Lib\site-packages\gpt_researcher\skills\context_manager.py:5
#       2 from typing import List, Dict, Optional, Set
#       4 from ..context.compression import ContextCompressor, WrittenContentCompressor, VectorstoreCompressor
# ----> 5 from ..actions.utils import stream_output
#       8 class ContextManager:
#       9     """Manages context for the researcher agent."""
#
# File C:\python\Lib\site-packages\gpt_researcher\actions\__init__.py:2
#       1 from .retriever import get_retriever, get_retrievers
# ----> 2 from .query_processing import plan_research_outline
#       3 from .agent_creator import extract_json_with_regex, choose_agent
#       4 from .web_scraping import scrape_urls
#
# File C:\python\Lib\site-packages\gpt_researcher\actions\query_processing.py:2
#       1 import json_repair
# ----> 2 from ..utils.llm import create_chat_completion
#       3 from ..prompts import generate_search_queries_prompt
#       4 from typing import Any, List, Dict
#
# File C:\python\Lib\site-packages\gpt_researcher\utils\llm.py:15
#      13 from ..prompts import generate_subtopics_prompt
#      14 from .costs import estimate_llm_cost
# ---> 15 from .validators import Subtopics
#      18 def get_llm(llm_provider, **kwargs):
#      19     from gpt_researcher.llm_provider import GenericLLMProvider
#
# File C:\python\Lib\site-packages\gpt_researcher\utils\validators.py:3
#       1 from typing import List
# ----> 3 from pydantic import BaseModel, Field
#       5 class Subtopic(BaseModel):
#       6     task: str = Field(description="Task name", min_length=1)
#
# File C:\python\Lib\site-packages\pydantic\__init__.py:421, in __getattr__(attr_name)
#     419     return result
#     420 else:
# --> 421     module = import_module(module_name, package=package)
#     422     result = getattr(module, attr_name)
#     423     g = globals()
#
# File C:\python\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File C:\python\Lib\site-packages\pydantic\fields.py:15
#      12 from typing import Any, Callable, ClassVar, TypeVar, cast, overload
#      13 from warnings import warn
# ---> 15 import annotated_types
#      16 import typing_extensions
#      17 from pydantic_core import PydanticUndefined
#
# ModuleNotFoundError: No module named 'annotated_types'

# %%
conda install annotated_types
# Out:
# Retrieving notices: ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - annotated_types
#
# Current channels:
#
#   - https://mirrors.sustech.edu.cn/anaconda/pkgs/main/win-64
#   - https://mirrors.sustech.edu.cn/anaconda/pkgs/main/noarch
#   - https://mirrors.sustech.edu.cn/anaconda/pkgs/free/win-64
#   - https://mirrors.sustech.edu.cn/anaconda/pkgs/free/noarch
#   - https://mirrors.sustech.edu.cn/anaconda/cloud/pytorch/win-64
#   - https://mirrors.sustech.edu.cn/anaconda/cloud/pytorch/noarch
#   - https://mirrors.sustech.edu.cn/anaconda-extra/cloud/nvidia/win-64
#   - https://mirrors.sustech.edu.cn/anaconda-extra/cloud/nvidia/noarch
#   - https://mirrors.sustech.edu.cn/anaconda/cloud/conda-forge/win-64
#   - https://mirrors.sustech.edu.cn/anaconda/cloud/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
